# %%
# %pip install mplfinance
import mplfinance as mpf
import tse_option as tso

# %%
tso.pricing_based_on_option("ضخود1208")
# Out:
# Stock Price: 3022	RiskFreeRate: 27.49%	HV: 37.73%
#           Strike Price Status Maturity(day) Open Interest  Bid  Ask Delta  \
# Symbol
# ضخود12081         2600    ITM            28             0  494  501  0.95
#
#           Leverage  BSM
# Symbol
# ضخود12081     5.73  483

# %%
df = tso.download_history("ضخود1208")
mpf.plot(df, type="candle")

# %%
tso.pricing_based_on_stock("فملی")
# Out:
# Stock Price: 7610 	RiskFreeRate: 27.49% 	HV: 30.69%
#           Strike Price Status Maturity(day) Open Interest   Bid   Ask Delta  \
# Symbol
# ضملي11701         5500    ITM             7             0  2000     0   1.0
# ضملي11731         7000    ITM             7             0    50     0  0.98
# ضملي11681         4500    ITM             7             0     0     0   1.0
# ضملي11671         4000    ITM             7             0   380     0   1.0
# ضملي11761         9000    OTM             7             0     0     0   0.0
# ضملي11751         8000    OTM             7             0    40     0  0.15
# ضملي11721         6500    ITM             7             0     0     0   1.0
# ضملي11711         6000    ITM             7             0  1200  1700   1.0
# ضملي11691         5000    ITM             7             0  1811  2700   1.0
# ضملي11661         3750    ITM             7             0   380     0   1.0
# ...

# %%
df = tso.download_history("شبریز",j_date=True,start="1400-01-01", adjust_price=False)
mpf.plot(df, type="candle")

# %%
df = tso.download_history("شبریز",j_date=True,start="1400-01-01", adjust_price=True,drop_unadjusted=True)
mpf.plot(df, type="candle")
