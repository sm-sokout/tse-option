# %% [markdown]
# ## installing

# %%
pip install tse-option

# %% [markdown]
# ## importing

# %%
import tse_option as tso

# %% [markdown]
# ## using (1)

# %% [markdown]
# با استفاده از تابع زیر، تمامی اختیار معامله های موجود روی سهم مورد نظر شما در خروجی نمایش داده می شود.

# %% [markdown]
# #### اختیار معامله های موجود روی سهم خساپا 1401/9/9

# %%
df = tso.pricing_based_on_stock(stock_name="خساپا", trading_days=100, IV=True, leverage=True, P_BSM=False, sort="Maturity")
df #sorted by time to maturity

#Strike Price = قیمت اعمال
#Status = وضعیت در سود یا ضرر بودن اختیار معامله
#Maturity(day) = زمان تا سررسید
#Open Interest = تعداد موقعیت های باز
#Bid = بهترین قیمت پیشنهادی برای خرید
#Ask = بهترین قیمتم پیشنهادی برای فروش
#Delta = دلتای اختیار معامله
#IV = تلاطم ضمنی
#Leverage = اهرم اختیار معامله
#BSM = قیمت تئوری اختیار معامله براساس مدل بلک-شولز-مرتون
#%Price/BSM = نسبت قیمت بازار به قیمت بلک-شولز-مرتون
# Out:
# Stock Price: 2032 	RiskFreeRate: 25.81% 	HV: 38.16%
#           Strike Price Status Maturity(day) Open Interest  Bid    Ask Delta  \
# Symbol
# ضسپا12111         3250    OTM            91             0  102    103  0.02
# ضسپا12131         1300    ITM            91             0    0      0   1.0
# ضسپا12121         1200    ITM            91             0  200      0   1.0
# ضسپا12141         1400    ITM            91             0  760    839  0.99
# ضسپا12021         1700    ITM            91             0  490    550  0.91
# ضسپا12001         1500    ITM            91             0  660    689  0.98
# ضسپا12031         1800    ITM            91             0  441    455  0.86
# ضسپا12011         1600    ITM            91             0  563    599  0.95
# ضسپا12091         2800    OTM            91             0  164    165  0.11
# ضسپا12071         2400    OTM            91             0  257    270  0.33
# ضسپا12041         1900    ITM            91             0  398    398  0.78
# ضسپا12061         2200    OTM            91             0  316    318  0.51
# ضسپا12051         2000    ATM            91             0  359    366   0.7
# ضسپا12101         3000    OTM            91             0  136    144  0.06
# ضسپا12081         2600    OTM            91             0  188    194   0.2
# ضسپا30211         1700    ITM           196             0  300  99999   0.9
# ضسپا30181         1400    ITM           196             0  300      0  0.98
# ضسپا30281         2800    OTM           196             0  300    500  0.31
# ضسپا30191         1500    ITM           196             0    0      0  0.96
# ضسپا30291         3000    OTM           196             0  210    400  0.23
# ضسپا30201         1600    ITM           196             0  710    735  0.93
# ضسپا30261         2400    OTM           196             0  320    365  0.52
# ضسپا30221         1800    ITM           196             0  200      0  0.86
# ضسپا30251         2200    OTM           196             0  415    475  0.64
# ضسپا30241         2000    ATM           196             0  461    549  0.76
# ضسپا30271         2600    OTM           196             0   73    575  0.41
# ضسپا30231         1900    ITM           196             0  300      0  0.81
#
#                IV Leverage  BSM
# Symbol
# ضسپا12111   %87.0     0.39    3
# ضسپا12131      %-      inf  814
# ضسپا12121      %-      inf  908
# ضسپا12141  %114.7      2.4  722
# ضسپا12021   %76.9     3.36  456
# ضسپا12001   %78.6     2.89  630
# ضسپا12031   %66.0     3.84  377
# ضسپا12011   %70.3     3.22  541
# ضسپا12091   %85.0     1.35   19
# ضسپا12071   %86.5     2.48   77
# ضسپا12041   %66.4     3.98  305
# ضسپا12061   %81.5     3.26  142
# ضسپا12051   %71.8     3.89  241
# ضسپا12101   %88.9     0.85    9
# ضسپا12081   %81.2     2.09   39
# ضسپا30211      %-     0.02  586
# ضسپا30181      %-      inf  821
# ضسپا30281  %106.7     1.26   98
# ضسپا30191      %-      inf  740
# ضسپا30291   %97.3     1.17   67
# ضسپا30201   %64.0     2.57  661
# ضسپا30261   %65.2     2.89  205
# ضسپا30221      %-      inf  515
# ضسپا30251   %71.8     2.74  286
# ضسپا30241   %70.1     2.81  390
# ضسپا30271  %111.2     1.45  143
# ضسپا30231      %-      inf  450

# %%
df = tso.pricing_based_on_stock(stock_name="خساپا", trading_days=100, IV=True, leverage=True, P_BSM=False, sort="Strike Price")
df #sorted by strike price
# Out:
# Stock Price: 2032 	RiskFreeRate: 25.81% 	HV: 38.16%
#           Strike Price Status Maturity(day) Open Interest  Bid    Ask Delta  \
# Symbol
# ضسپا12121         1200    ITM            91             0  200      0   1.0
# ضسپا12131         1300    ITM            91             0    0      0   1.0
# ضسپا30181         1400    ITM           196             0  300      0  0.98
# ضسپا12141         1400    ITM            91             0  760    839  0.99
# ضسپا30191         1500    ITM           196             0    0      0  0.96
# ضسپا12001         1500    ITM            91             0  660    689  0.98
# ضسپا12011         1600    ITM            91             0  563    599  0.95
# ضسپا30201         1600    ITM           196             0  710    735  0.93
# ضسپا30211         1700    ITM           196             0  300  99999   0.9
# ضسپا12021         1700    ITM            91             0  490    550  0.91
# ضسپا12031         1800    ITM            91             0  441    455  0.86
# ضسپا30221         1800    ITM           196             0  200      0  0.86
# ضسپا30231         1900    ITM           196             0  300      0  0.81
# ضسپا12041         1900    ITM            91             0  398    398  0.78
# ضسپا30241         2000    ATM           196             0  461    549  0.76
# ضسپا12051         2000    ATM            91             0  359    366   0.7
# ضسپا12061         2200    OTM            91             0  316    318  0.51
# ضسپا30251         2200    OTM           196             0  415    475  0.64
# ضسپا30261         2400    OTM           196             0  320    365  0.52
# ضسپا12071         2400    OTM            91             0  257    270  0.33
# ضسپا30271         2600    OTM           196             0   73    575  0.41
# ضسپا12081         2600    OTM            91             0  188    194   0.2
# ضسپا12091         2800    OTM            91             0  164    165  0.11
# ضسپا30281         2800    OTM           196             0  300    500  0.31
# ضسپا12101         3000    OTM            91             0  136    144  0.06
# ضسپا30291         3000    OTM           196             0  210    400  0.23
# ضسپا12111         3250    OTM            91             0  102    103  0.02
#
#                IV Leverage  BSM
# Symbol
# ضسپا12121      %-      inf  908
# ضسپا12131      %-      inf  814
# ضسپا30181      %-      inf  821
# ضسپا12141  %114.7      2.4  722
# ضسپا30191      %-      inf  740
# ضسپا12001   %78.6     2.89  630
# ضسپا12011   %70.3     3.22  541
# ضسپا30201   %64.0     2.57  661
# ضسپا30211      %-     0.02  586
# ضسپا12021   %76.9     3.36  456
# ضسپا12031   %66.0     3.84  377
# ضسپا30221      %-      inf  515
# ضسپا30231      %-      inf  450
# ضسپا12041   %66.4     3.98  305
# ضسپا30241   %70.1     2.81  390
# ضسپا12051   %71.8     3.89  241
# ضسپا12061   %81.5     3.26  142
# ضسپا30251   %71.8     2.74  286
# ضسپا30261   %65.2     2.89  205
# ضسپا12071   %86.5     2.48   77
# ضسپا30271  %111.2     1.45  143
# ضسپا12081   %81.2     2.09   39
# ضسپا12091   %85.0     1.35   19
# ضسپا30281  %106.7     1.26   98
# ضسپا12101   %88.9     0.85    9
# ضسپا30291   %97.3     1.17   67
# ضسپا12111   %87.0     0.39    3

# %% [markdown]
# علاوه بر موارد فوق می توان مرتب سازی را براساس تعداد موقعیت های باز هر اختیار معامله انجام داد

# %% [markdown]
# همچنین می توان با تغییراتی در آرگومان های ورودی، نمایش برخی از ستون ها را غیرفعال کرد. این قابلیت برای ستون هایی همچون "تلاطم ضمنی"، "اهرم" و "نسبت قیمت بازار به قیمت بلک-شولز" وجود دارد.

# %% [markdown]
# ## using (2)

# %% [markdown]
# با استفاده از تابع زیر، اطلاعات یک اختیار معامله خاص به شما نمایش داده می شود.

# %% [markdown]
# #### اطلاعات اختیار معامله ضسپا1205 1401/9/9

# %%
df = tso.pricing_based_on_option(option_name="ضسپا1205", trading_days=100, IV=True, leverage=True, P_BSM=True)
df
# Out:
# Stock Price: 2032	RiskFreeRate: 25.8%	HV: 38.16%
#           Strike Price Status Maturity(day) Open Interest  Bid  Ask Delta  \
# Symbol
# ضسپا12051         2000    ATM            91             0  359  366   0.7
#
#               IV Leverage  BSM %Price/BSM
# Symbol
# ضسپا12051  %71.9     3.89  241    %-51.9🔴

# %% [markdown]
# ستون "نسبت قیمت بازار به قیمت بلک-شولز" بیانگر میزان overvalue یا undervalue بودن اختیار را نشان می دهد.

# %% [markdown]
# **توجه**: کلیه خروجی این ماژول از جمله قیمت گذاری و محاسبه تلاطم ضمنی و ... به جهت تسهیل در تصمیم گیری سرمایه گذاران است و هیچگونه پیشنهادی برای خرید یا فروش آن محسوب نمی شود. لذا تمامی عواقب سرمایه گذاری به عهده شخص سرمایه گذار است و توسعه دهندگان هیچ مسئولیتی در قبال زیان های احتمالی ندارند.
